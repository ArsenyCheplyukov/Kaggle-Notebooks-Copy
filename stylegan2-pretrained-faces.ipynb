# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch

# %%
# !python ./stylegan2-ada-pytorch/generate.py --outdir=out --network=https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl --seeds=0-35

# %%
# !zip -r file.zip ./out
