# %%
# !pip install -U torch
# !pip install -U torchaudio
# !apt-get install -y libsndfile1 ffmpeg
# !pip install -U Cython
# !pip install -U nemo_toolkit[all]
#!pip uninstall scikit-learn -y
#!pip install scikit-learn==0.23.2
#!pip install tslearn

# %%
# !git clone https://github.com/NVIDIA/apex
# !python ./apex/setup.py install

# %%
import nemo
import nemo.collections.asr as nemo_asr
model = nemo_asr.models.EncDecClassificationModel.from_pretrained(model_name="commandrecognition_en_matchboxnet3x2x64_v2_subset_task")

# %%
print(nemo_asr.models.EncDecClassificationModel.list_available_models())

# %%
print(model.transcribe(paths2audio_files=["../input/synthetic-speech-commands-dataset/augmented_dataset_verynoisy/augmented_dataset_verynoisy/bed/1001.wav"]))
