# %%
# !pip install rpunct
# !pip install torchaudio==0.8.1

# %%
import rpunct
from rpunct import RestorePuncts
# The default language is 'english'
rpunct = RestorePuncts()

# %%
help(rpunct)

# %%
help(RestorePuncts)

# %%
rpunct.punctuate("""excuse me can you help me""")
