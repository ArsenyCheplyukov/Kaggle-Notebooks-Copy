# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# %%
! git clone https://github.com/ultralytics/yolov5

# %%
# !pip install -r ./yolov5/requirements.txt

# %%
#!pip install wandb
#import wandb
#wandb.login(key='e8f832e4ea7ab2935507e012b52cd7484c683360')

# %%
# !python ./yolov5/train.py --img 512 --batch 64 --epochs 8 --data ../input/d/arsenycheplukov/datatofruit/data.yaml --cfg ./yolov5/models/yolov5s.yaml --name yolov5x_fold0_new --cache --weights yolov5s.pt

# %%
# !python ./yolov5/detect.py --weights runs/train/yolov5x_fold0_new4/weights/best.pt --img 512 --conf 0.045 --source ../input/fanstorchyolov5/fans/test

# %%
from IPython.display import Image, clear_output  # to display images

Image(filename='runs/detect/exp14/t12.jpg', width=800)  # train batch 0 mosaics and labels
