# %%
# !git clone https://github.com/rosinality/stylegan2-pytorch
# !pip install ninja #required dependency for stylegan2-pytorch
# !pip install gdown

# %%
# !gdown --id 1-04MHpxTbU4fNBwRtjZKSYCYS6xP2Ti9

# %%
pkl_file = "./2020-01-11-skylion-stylegan2-animeportraits-networksnapshot-024664.pt" # copy and paste path from sidebar

# %%
# !mkdir sample

# %%
# !python ./stylegan2-pytorch/generate.py --size 896 --sample 10 --ckpt ./2020-01-11-skylion-stylegan2-animeportraits-networksnapshot-024664.pt

# %%
# !zip -r file.zip ./sample
